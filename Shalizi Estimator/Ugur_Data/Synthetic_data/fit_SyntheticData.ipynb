# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
import matplotlib.font_manager as font_manager
import matplotlib.ticker
import pylab as p
from matplotlib.axis import Axis
import igraph as ig

from scipy.optimize import curve_fit
import scipy.optimize as optimize
import os
from numpy import random
import statistics


from scipy.special import psi
from PIL import Image

# %%
#
#  Here write down your directory that you put all the files in your computer
#

os.chdir("/Users/tirnakli/MY-WORKS/Kenrik_fit/q-exp/Github/Synthetic_data/")

Image.open('q_exp_dev.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1608x358 at 0x7FD2800EF550>

# %%
#
#  Here write down your directory that you put all the files in your computer
#

os.chdir("/Users/tirnakli/MY-WORKS/Kenrik_fit/q-exp/Github/Synthetic_data/")

Image.open('find_q_beta.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1458x1464 at 0x7FD2800EFBB0>

# %%
#
#  Here write down your directory that you put all the files in your computer
#

os.chdir("/Users/tirnakli/MY-WORKS/Kenrik_fit/q-exp/Github/Synthetic_data/")

# %%
#
#  These data have been obtained from   
#
#               q_estimates_directly_synthetic.py   
#
#  In this py code, 
#
#      ss = ....
#       s = ....
#
#  and
#
#      s = s + ???
#
#  must be arranged manually for detecting correct (q, beta) pair.
#


qval_n25M = np.loadtxt("q_estimates_for_q1.50565_beta4484.0_with_500expr_n25000000.txt")
betaval_n25M = np.loadtxt("beta_estimates_for_q1.50565_beta4484.0_with_500expr_n25000000.txt")

qval_n15M = np.loadtxt("q_estimates_for_q1.50565_beta4484.0_with_500expr_n15000000.txt")
betaval_n15M = np.loadtxt("beta_estimates_for_q1.50565_beta4484.0_with_500expr_n15000000.txt")

qval_n9M = np.loadtxt("q_estimates_for_q1.50565_beta4484.0_with_500expr_n9000000.txt")
betaval_n9M = np.loadtxt("beta_estimates_for_q1.50565_beta4484.0_with_500expr_n9000000.txt")

qval_n5M = np.loadtxt("q_estimates_for_q1.50565_beta4484.0_with_500expr_n5000000.txt")
betaval_n5M = np.loadtxt("beta_estimates_for_q1.50565_beta4484.0_with_500expr_n5000000.txt")

qval_n2500b = np.loadtxt("q_estimates_for_q1.50565_beta4484.0_with_500expr_n2500000.txt")
betaval_n2500b = np.loadtxt("beta_estimates_for_q1.50565_beta4484.0_with_500expr_n2500000.txt")

qval_n1M = np.loadtxt("q_estimates_for_q1.50565_beta4484.0_with_500expr_n1000000.txt")
betaval_n1M = np.loadtxt("beta_estimates_for_q1.50565_beta4484.0_with_500expr_n1000000.txt")

qval_n300b = np.loadtxt("q_estimates_for_q1.50565_beta4484.0_with_500expr_n300000.txt")
betaval_n300b = np.loadtxt("beta_estimates_for_q1.50565_beta4484.0_with_500expr_n300000.txt")

qval_n75b = np.loadtxt("q_estimates_for_q1.50565_beta4484.0_with_500expr_n75000.txt")
betaval_n75b = np.loadtxt("beta_estimates_for_q1.50565_beta4484.0_with_500expr_n75000.txt")

# %%
print('q (median)=',statistics.median(qval_n25M))
print('q (percentile95)=',np.percentile(qval_n25M, 95))
print('q (percentile05)=',np.percentile(qval_n25M, 5))
print(' ')
print('beta (median)=',statistics.median(betaval_n25M))
print('beta (percentile95)=',np.percentile(betaval_n25M, 95))
print('beta (percentile05)=',np.percentile(betaval_n25M, 5))
print(' ')
print(' ')

print('q (median)=',statistics.median(qval_n15M))
print('q (percentile95)=',np.percentile(qval_n15M, 95))
print('q (percentile05)=',np.percentile(qval_n15M, 5))
print(' ')
print('beta (median)=',statistics.median(betaval_n15M))
print('beta (percentile95)=',np.percentile(betaval_n15M, 95))
print('beta (percentile05)=',np.percentile(betaval_n15M, 5))
print(' ')
print(' ')

print('q (median)=',statistics.median(qval_n9M))
print('q (percentile95)=',np.percentile(qval_n9M, 95))
print('q (percentile05)=',np.percentile(qval_n9M, 5))
print(' ')
print('beta (median)=',statistics.median(betaval_n9M))
print('beta (percentile95)=',np.percentile(betaval_n9M, 95))
print('beta (percentile05)=',np.percentile(betaval_n9M, 5))
print(' ')
print(' ')

print('q (median)=',statistics.median(qval_n5M))
print('q (percentile95)=',np.percentile(qval_n5M, 95))
print('q (percentile05)=',np.percentile(qval_n5M, 5))
print(' ')
print('beta (median)=',statistics.median(betaval_n5M))
print('beta (percentile95)=',np.percentile(betaval_n5M, 95))
print('beta (percentile05)=',np.percentile(betaval_n5M, 5))
print(' ')
print(' ')


print('q (median)=',statistics.median(qval_n2500b))
print('q (percentile95)=',np.percentile(qval_n2500b, 95))
print('q (percentile05)=',np.percentile(qval_n2500b, 5))
print(' ')
print('beta (median)=',statistics.median(betaval_n2500b))
print('beta (percentile95)=',np.percentile(betaval_n2500b, 95))
print('beta (percentile05)=',np.percentile(betaval_n2500b, 5))
print(' ')
print(' ')


print('q (median)=',statistics.median(qval_n1M))
print('q (percentile95)=',np.percentile(qval_n1M, 95))
print('q (percentile05)=',np.percentile(qval_n1M, 5))
print(' ')
print('beta (median)=',statistics.median(betaval_n1M))
print('beta (percentile95)=',np.percentile(betaval_n1M, 95))
print('beta (percentile05)=',np.percentile(betaval_n1M, 5))
print(' ')
print(' ')

print('q (median)=',statistics.median(qval_n300b))
print('q (percentile95)=',np.percentile(qval_n300b, 95))
print('q (percentile05)=',np.percentile(qval_n300b, 5))
print(' ')
print('beta (median)=',statistics.median(betaval_n300b))
print('beta (percentile95)=',np.percentile(betaval_n300b, 95))
print('beta (percentile05)=',np.percentile(betaval_n300b, 5))
print(' ')
print(' ')
# Out:
# q (median)= 1.5056600340481148
# q (percentile95)= 1.5057630735597118
# q (percentile05)= 1.505560095930121
#
# beta (median)= 4484.381152064381
# beta (percentile95)= 4485.195541250388
# beta (percentile05)= 4483.4162061863535
#
#
# q (median)= 1.5056547013778847
# q (percentile95)= 1.5059054454629701
# q (percentile05)= 1.5053713567748754
#
# beta (median)= 4484.382336682873
# beta (percentile95)= 4491.82848287794
# beta (percentile05)= 4476.757992869448
#
#
# q (median)= 1.505662039024649
# q (percentile95)= 1.5059822448266305
# q (percentile05)= 1.5053487021879008
#
# beta (median)= 4484.3660807906
# beta (percentile95)= 4492.464712073945
# beta (percentile05)= 4476.347202877817
#
#
# q (median)= 1.5056722113393683
# q (percentile95)= 1.5060642352731468
# q (percentile05)= 1.5052523125922914
#
# beta (median)= 4484.148386282071
# beta (percentile95)= 4493.3632791956625
# beta (percentile05)= 4475.47442416183
#
#
# q (median)= 1.5056409998788083
# ...

# %%
fig, ax1 = plt.subplots(figsize=(12, 10))
ax1 = plt.axes(xscale='log',yscale='linear')

ax1.tick_params(bottom=True, top=True, left=True, right=True)

#ax1.axis([20000, 60000000, 0.01, .02])
ax1.set_xlim(20000, 55000000)


Axis.set_label_coords(ax1.yaxis,-0.12 , 0.5)


for axis in ['top','bottom','left','right']:
    ax1.spines[axis].set_linewidth(2)
    ax1.spines[axis].set_zorder(0)


plt.rc('text', usetex=True)
plt.rc('font', family='Times New Roman')


ax1.xaxis.tick_bottom()
#ax1.yaxis.tick_left()
#ax1.yaxis.tick_right()


ax1.set_xlabel(r'Sample Size',fontsize=40)
ax1.set_ylabel(r'$q$',fontsize=40,rotation=0)
ax1.tick_params(axis='y', which='major', labelsize=25, direction='in',length=10, width=2,grid_linewidth=2,labelright=True)
ax1.tick_params(axis='y', which='minor', labelsize=20, direction='in',length=6, width=2,grid_linewidth=2)
ax1.tick_params(axis='x', which='major', labelsize=25, direction='in',length=10,width=2)
ax1.tick_params(axis='x', which='minor', labelsize=20, direction='in',length=6,width=2)
ax1.tick_params(direction='in', pad=10)


xx=np.arange(20000,55000000,1)
yy=xx*0+ 1.50565
ax1.plot(xx,yy, '--', lw=2.5, c='red')


#ax1.text(10, 0.01, '\# of experiments = 500', fontsize=33);


n = 25000000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(qval_n25M)-np.percentile(qval_n25M, 5), np.percentile(qval_n25M, 95)-statistics.median(qval_n25M))]).T
ax1.errorbar(n, statistics.median(qval_n25M), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)

n = 15000000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(qval_n15M)-np.percentile(qval_n15M, 5), np.percentile(qval_n15M, 95)-statistics.median(qval_n15M))]).T
ax1.errorbar(n, statistics.median(qval_n15M), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)

n = 9000000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(qval_n9M)-np.percentile(qval_n9M, 5), np.percentile(qval_n9M, 95)-statistics.median(qval_n9M))]).T
ax1.errorbar(n, statistics.median(qval_n9M), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)

n = 5000000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(qval_n5M)-np.percentile(qval_n5M, 5), np.percentile(qval_n5M, 95)-statistics.median(qval_n5M))]).T
ax1.errorbar(n, statistics.median(qval_n5M), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)

n = 2500000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(qval_n2500b)-np.percentile(qval_n2500b, 5), np.percentile(qval_n2500b, 95)-statistics.median(qval_n2500b))]).T
ax1.errorbar(n, statistics.median(qval_n2500b), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)


n = 1000000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(qval_n1M)-np.percentile(qval_n1M, 5), np.percentile(qval_n1M, 95)-statistics.median(qval_n1M))]).T
ax1.errorbar(n, statistics.median(qval_n1M), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)

n = 300000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(qval_n300b)-np.percentile(qval_n300b, 5), np.percentile(qval_n300b, 95)-statistics.median(qval_n300b))]).T
ax1.errorbar(n, statistics.median(qval_n300b), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)

n = 75000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(qval_n75b)-np.percentile(qval_n75b, 5), np.percentile(qval_n75b, 95)-statistics.median(qval_n75b))]).T
ax1.errorbar(n, statistics.median(qval_n75b), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)


ax1.text(1000000, 1.508, '\# of experiments = 500', fontsize=33);


label_x = 10000000
label_y = 1.5067
arrow_x = 55000000
arrow_y = 1.50565

arrow_properties = dict(
    facecolor="black", width=0.75,
    headwidth=10, shrink=0.01)
plt.annotate(
    "1.50565", fontsize=30, xy=(arrow_x, arrow_y),
    xytext=(label_x, label_y),
    arrowprops=arrow_properties)
# Out:
# Text(10000000, 1.5067, '1.50565')

# %%
fig, ax1 = plt.subplots(figsize=(12, 10))
ax1 = plt.axes(xscale='log',yscale='linear')

ax1.tick_params(bottom=True, top=True, left=True, right=True)

#ax1.axis([3, 900000, 0.01, .02])
ax1.set_xlim(20000, 55000000)

Axis.set_label_coords(ax1.yaxis,-0.12 , 0.5)

for axis in ['top','bottom','left','right']:
    ax1.spines[axis].set_linewidth(2)
    ax1.spines[axis].set_zorder(0)


plt.rc('text', usetex=True)
plt.rc('font', family='Times New Roman')


ax1.xaxis.tick_bottom()
#ax1.yaxis.tick_left()
#ax1.yaxis.tick_right()


ax1.set_xlabel(r'Sample Size',fontsize=40)
ax1.set_ylabel(r'$\beta$',fontsize=40,rotation=0)
ax1.tick_params(axis='y', which='major', labelsize=25, direction='in',length=10, width=2,grid_linewidth=2,labelright=True)
ax1.tick_params(axis='y', which='minor', labelsize=20, direction='in',length=6, width=2,grid_linewidth=2)
ax1.tick_params(axis='x', which='major', labelsize=25, direction='in',length=10,width=2)
ax1.tick_params(axis='x', which='minor', labelsize=20, direction='in',length=6,width=2)
ax1.tick_params(direction='in', pad=10)

xx=np.arange(20000,55000000,1)
yy=xx*0+ 4484
ax1.plot(xx,yy, '--', lw=2.5, c='red')



n = 25000000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(betaval_n25M)-np.percentile(betaval_n25M, 5), np.percentile(betaval_n25M, 95)-statistics.median(betaval_n25M))]).T
ax1.errorbar(n, statistics.median(betaval_n25M), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)

n = 15000000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(betaval_n15M)-np.percentile(betaval_n15M, 5), np.percentile(betaval_n15M, 95)-statistics.median(betaval_n15M))]).T
ax1.errorbar(n, statistics.median(betaval_n15M), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)

n = 9000000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(betaval_n9M)-np.percentile(betaval_n9M, 5), np.percentile(betaval_n9M, 95)-statistics.median(betaval_n9M))]).T
ax1.errorbar(n, statistics.median(betaval_n9M), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)

n = 5000000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(betaval_n5M)-np.percentile(betaval_n5M, 5), np.percentile(betaval_n5M, 95)-statistics.median(betaval_n5M))]).T
ax1.errorbar(n, statistics.median(betaval_n5M), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)

n = 2500000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(betaval_n2500b)-np.percentile(betaval_n2500b, 5), np.percentile(betaval_n2500b, 95)-statistics.median(betaval_n2500b))]).T
ax1.errorbar(n, statistics.median(betaval_n2500b), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)


n = 1000000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(betaval_n1M)-np.percentile(betaval_n1M, 5), np.percentile(betaval_n1M, 95)-statistics.median(betaval_n1M))]).T
ax1.errorbar(n, statistics.median(betaval_n1M), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)

n = 300000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(betaval_n300b)-np.percentile(betaval_n300b, 5), np.percentile(betaval_n300b, 95)-statistics.median(betaval_n300b))]).T
ax1.errorbar(n, statistics.median(betaval_n300b), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)

n = 75000
#yerr= max(qval_n5000)-((min(qval_n5000)+max(qval_n5000))/2)
yerr = np.array([(statistics.median(betaval_n75b)-np.percentile(betaval_n75b, 5), np.percentile(betaval_n75b, 95)-statistics.median(betaval_n75b))]).T
ax1.errorbar(n, statistics.median(betaval_n75b), yerr=yerr,fmt='.',markersize=20,c='blue',capsize=10,elinewidth=2.5)


ax1.text(1000000, 4545, '\# of experiments = 500', fontsize=33);


label_x = 10000000
label_y = 4512
arrow_x = 55000000
arrow_y = 4484

arrow_properties = dict(
    facecolor="black", width=0.75,
    headwidth=10, shrink=0.01)
plt.annotate(
    "4484", fontsize=30, xy=(arrow_x, arrow_y),
    xytext=(label_x, label_y),
    arrowprops=arrow_properties)
# Out:
# Text(10000000, 4512, '4484')
